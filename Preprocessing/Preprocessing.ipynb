# %%
from sklearn.feature_extraction.text import CountVectorizer
from pyvi import ViTokenizer
import pandas as pd
import re

# %%
df = pd.read_csv('data_after_remove.csv', index_col=0)
df.head(5)
# Out:
#                                                Title  \
# 0                            31 Tuổi Thì Đã Làm Sao?
# 1  Nền Kinh Tế Thị Trường Và Chính Sách Hai Đồng ...
# 2                                        PR Hiệu Quả
# 3               Lịch Sử Kiến Trúc Thế Giới - Quyển 1
# 4      Chuyện Chú Chim, Con Ếch Và Khu Vườn Màu Xanh
#
#                                                 Link                  Genre  \
# 0  https://khosachonline.com/sach/31-tuoi-thi-da-...  Tâm Lý - Kỹ Năng Sống
# 1  https://khosachonline.com/sach/nen-kinh-te-thi...      Kinh Tế - Quản Lý
# 2         https://khosachonline.com/sach/pr-hieu-qua   Marketing - Bán hàng
# 3  https://khosachonline.com/sach/lich-su-kien-tr...   Kiến Trúc - Xây Dựng
# 4  https://khosachonline.com/sach/chuyen-chu-chim...  Tâm Lý - Kỹ Năng Sống
#
#                  Author                                        Description
# 0        Fumio Yamamoto  Giờ đây tôi đã 31 tuổi, à không, tôi mới chỉ 3...
# 1          Đỗ Đức Lương  Nền Kinh Tế Thị Trường Và Chính Sách Hai Đồng ...
# 2               Moi Ali  Những kỹ năng thực tế giúp bạn cách phát triển...
# 3        Trần Trọng Chi  Cuốn sách sẻ giới thiêu đến bạn đọc các kiểu k...
# 4  Elizabeth O. Dulemba  TỪ BỎ Ư? TRONG TỪ ĐIỂN CỦA TÔI KHÔNG CÓ HAI TỪ...

# %%
for index, row in df.iterrows():
    row['Description'] = ViTokenizer.tokenize(row['Description'])

# %%
df['Description'] = df['Description'].apply(str.lower)
df
# Out:
#                                                  Title  \
# 0                              31 Tuổi Thì Đã Làm Sao?
# 1    Nền Kinh Tế Thị Trường Và Chính Sách Hai Đồng ...
# 2                                          PR Hiệu Quả
# 3                 Lịch Sử Kiến Trúc Thế Giới - Quyển 1
# 4        Chuyện Chú Chim, Con Ếch Và Khu Vườn Màu Xanh
# ..                                                 ...
# 978              10 Bí Quyết Thành Công Của Bill Gates
# 979               Kỹ Năng Tạo Ảnh Hưởng Đến Người Khác
# 980                 206 Món Canh Dinh Dưỡng Cho Trẻ Em
# Và Người Bệnh
# 982  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
#
#                                                   Link                  Genre  \
# 0    https://khosachonline.com/sach/31-tuoi-thi-da-...  Tâm Lý - Kỹ Năng Sống
# 1    https://khosachonline.com/sach/nen-kinh-te-thi...      Kinh Tế - Quản Lý
# 2           https://khosachonline.com/sach/pr-hieu-qua   Marketing - Bán hàng
# 3    https://khosachonline.com/sach/lich-su-kien-tr...   Kiến Trúc - Xây Dựng
# 4    https://khosachonline.com/sach/chuyen-chu-chim...  Tâm Lý - Kỹ Năng Sống
# ..                                                 ...                    ...
# 978  https://khosachonline.com/sach/10-bi-quyet-tha...   Marketing - Bán hàng
# 979  https://khosachonline.com/sach/ky-nang-tao-anh...  Tâm Lý - Kỹ Năng Sống
# 980  https://khosachonline.com/sach/206-mon-canh-di...       Ẩm thực - Nấu ăn
# 981  https://khosachonline.com/sach/120-mon-sup-bo-...       Ẩm thực - Nấu ăn
# 982  https://khosachonline.com/sach/cac-an-so-chinh...    Lịch Sử - Chính Trị
#
#                    Author                                        Description
# 0          Fumio Yamamoto  giờ_đây tôi đã 31 tuổi , à không , tôi mới chỉ...
# 1            Đỗ Đức Lương  nền kinh_tế thị_trường và chính_sách hai đồng_...
# 2                 Moi Ali  những kỹ_năng thực_tế giúp bạn cách phát_triển...
# 3          Trần Trọng Chi  cuốn sách sẻ giới thiêu đến bạn_đọc các kiểu k...
# 4    Elizabeth O. Dulemba  từ_bỏ ư ? trong từ_điển của tôi không có hai t...
# ..                    ...                                                ...
# 978          Des Dearlove  sau quá_trình nghiên_cứu nghiêm_túc và lâu_dài...
# 979           Roy Johnson  để trở_thành một người quản_lý giỏi thì yếu_tố...
# 980              Mai Ngọc  nội_dung bao_gồm : \n canh cá_chép mã_thầy \n ...
# 981               Mỹ Hạnh  120 món súp bổ_dưỡng cho trẻ_em & người_bệnh v...
# 982       Nguyễn Ngọc Huy  một tác_phẩm đặc_biệt rất hay mặc_dù đề_tài ch...
#
# [983 rows x 5 columns]

# %%
with open('vietnamese-stopwords-dash.txt','r', encoding='utf-8') as f:
    sw = f.readlines()
sw = [i[:-1] for i in sw]

# %%
def stopwords(text):
    text = [word.lower() for word in text.split() if word.lower() not in sw]
    return " ".join(text).strip()

# %%
df['Description'] = df['Description'].apply(stopwords)

# %%
def remove_punctuation(text):
    vietnamese_text = re.sub(r'[^a-zA-Z0123456789àáạảãâầấậẩẫăằắặẳẵèéẹẻẽêềếệểễìíịỉĩòóọỏõôồốộổỗơờớợởỡùúụủũưừứựửữỳýỵỷỹđÀÁẠẢÃÂẦẤẬẨẪĂẰẮẶẲẴÈÉẸẺẼÊỀẾỆỂỄÌÍỊỈĨÒÓỌỎÕÔỒỐỘỔỖƠỜỚỢỞỠÙÚỤỦŨƯỪỨỰỬỮỲÝỴỶỸĐ\s]', '', text.lower())
    return vietnamese_text.lower()

# %%
df['Description'] = df['Description'].apply(remove_punctuation)

# %%
df
# Out:
#                                                  Title  \
# 0                              31 Tuổi Thì Đã Làm Sao?
# 1    Nền Kinh Tế Thị Trường Và Chính Sách Hai Đồng ...
# 2                                          PR Hiệu Quả
# 3                 Lịch Sử Kiến Trúc Thế Giới - Quyển 1
# 4        Chuyện Chú Chim, Con Ếch Và Khu Vườn Màu Xanh
# ..                                                 ...
# 978              10 Bí Quyết Thành Công Của Bill Gates
# 979               Kỹ Năng Tạo Ảnh Hưởng Đến Người Khác
# 980                 206 Món Canh Dinh Dưỡng Cho Trẻ Em
# Và Người Bệnh
# 982  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
#
#                                                   Link                  Genre  \
# 0    https://khosachonline.com/sach/31-tuoi-thi-da-...  Tâm Lý - Kỹ Năng Sống
# 1    https://khosachonline.com/sach/nen-kinh-te-thi...      Kinh Tế - Quản Lý
# 2           https://khosachonline.com/sach/pr-hieu-qua   Marketing - Bán hàng
# 3    https://khosachonline.com/sach/lich-su-kien-tr...   Kiến Trúc - Xây Dựng
# 4    https://khosachonline.com/sach/chuyen-chu-chim...  Tâm Lý - Kỹ Năng Sống
# ..                                                 ...                    ...
# 978  https://khosachonline.com/sach/10-bi-quyet-tha...   Marketing - Bán hàng
# 979  https://khosachonline.com/sach/ky-nang-tao-anh...  Tâm Lý - Kỹ Năng Sống
# 980  https://khosachonline.com/sach/206-mon-canh-di...       Ẩm thực - Nấu ăn
# 981  https://khosachonline.com/sach/120-mon-sup-bo-...       Ẩm thực - Nấu ăn
# 982  https://khosachonline.com/sach/cac-an-so-chinh...    Lịch Sử - Chính Trị
#
#                    Author                                        Description
# 0          Fumio Yamamoto  31   31   31  bụngdưới lễphục size phẳngphiu  ...
# 1            Đỗ Đức Lương  kinhtế thịtrường chínhsách hai đồngnộitệ thông...
# 2                 Moi Ali  kỹnăng giúp pháttriển kỹnăng côngtác pr duytrì...
# 3          Trần Trọng Chi  sách sẻ giới thiêu bạnđọc kiểu kiếntrúc nổitiế...
# 4    Elizabeth O. Dulemba  từbỏ  từđiển hai đấy  rơi tậncùng chánnản  buô...
# ..                    ...                                                ...
# 978          Des Dearlove  nghiêncứu nghiêmtúc lâudài  tácgiả đúckết thàn...
# 979           Roy Johnson  quảnlý giỏi yếutố kỹnăng xâydựng quanhệ hợptác...
# 980              Mai Ngọc  nộidung baogồm  canh cáchép mãthầy canh táo đậ...
# 981               Mỹ Hạnh  120 món súp bổdưỡng trẻem  ngườibệnh món  1  m...
# 982       Nguyễn Ngọc Huy  tácphẩm mặcdù đềtài tiểuthuyết võ hiệp vốn trà...
#
# [983 rows x 5 columns]

# %%
from nltk import ngrams

# %%
def split_description_with_ngrams(df, n):
    # Create a new column to store the n-gram split data
    df['Description_Ngrams'] = df['Description'].apply(lambda x: split_data_with_ngrams(x, n))
    return df

def split_data_with_ngrams(data, n):
    # Tokenize the data into words or characters, depending on your requirements
    tokens = data.split()  # Change this to split by characters if needed

    # Generate n-grams
    ngram_list = list(ngrams(tokens, n))

    return ngram_list

# %%
ngram_size = 20
df = split_description_with_ngrams(df, ngram_size)
df.shape
# Out:
# (983, 6)

# %%
df=df.explode('Description_Ngrams')
df = df.reset_index(drop=True)
df.head()
# Out:
#                      Title                                               Link  \
# 0  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 1  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 2  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 3  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 4  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
#
#                    Genre          Author  \
# 0  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 1  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 2  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 3  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 4  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
#
#                                          Description  \
# 0  31   31   31  bụngdưới lễphục size phẳngphiu  ...
# 1  31   31   31  bụngdưới lễphục size phẳngphiu  ...
# 2  31   31   31  bụngdưới lễphục size phẳngphiu  ...
# 3  31   31   31  bụngdưới lễphục size phẳngphiu  ...
# 4  31   31   31  bụngdưới lễphục size phẳngphiu  ...
#
#                                   Description_Ngrams
# 0  (31, 31, 31, bụngdưới, lễphục, size, phẳngphiu...
# 1  (31, 31, bụngdưới, lễphục, size, phẳngphiu, tư...
# 2  (31, bụngdưới, lễphục, size, phẳngphiu, tưởngt...
# 3  (bụngdưới, lễphục, size, phẳngphiu, tưởngtượng...
# 4  (lễphục, size, phẳngphiu, tưởngtượng, mẹ, đứa,...

# %%
df['Description'] = df.apply(lambda x: ' '.join(x['Description_Ngrams']) if isinstance(x['Description_Ngrams'], tuple) else x['Description'], axis=1)
df
# Out:
#                                                    Title  \
# 0                                31 Tuổi Thì Đã Làm Sao?
# 1                                31 Tuổi Thì Đã Làm Sao?
# 2                                31 Tuổi Thì Đã Làm Sao?
# 3                                31 Tuổi Thì Đã Làm Sao?
# 4                                31 Tuổi Thì Đã Làm Sao?
# ...                                                  ...
# 29396  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
# 29397  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
# 29398  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
# 29399  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
# 29400  Các Ẩn Số Chính Trị Trong Tiểu Thuyết Võ Hiệp ...
#
#                                                     Link  \
# 0      https://khosachonline.com/sach/31-tuoi-thi-da-...
# 1      https://khosachonline.com/sach/31-tuoi-thi-da-...
# 2      https://khosachonline.com/sach/31-tuoi-thi-da-...
# 3      https://khosachonline.com/sach/31-tuoi-thi-da-...
# 4      https://khosachonline.com/sach/31-tuoi-thi-da-...
# ...                                                  ...
# 29396  https://khosachonline.com/sach/cac-an-so-chinh...
# 29397  https://khosachonline.com/sach/cac-an-so-chinh...
# 29398  https://khosachonline.com/sach/cac-an-so-chinh...
# 29399  https://khosachonline.com/sach/cac-an-so-chinh...
# 29400  https://khosachonline.com/sach/cac-an-so-chinh...
#
#                        Genre           Author  \
# 0      Tâm Lý - Kỹ Năng Sống   Fumio Yamamoto
# 1      Tâm Lý - Kỹ Năng Sống   Fumio Yamamoto
# 2      Tâm Lý - Kỹ Năng Sống   Fumio Yamamoto
# 3      Tâm Lý - Kỹ Năng Sống   Fumio Yamamoto
# 4      Tâm Lý - Kỹ Năng Sống   Fumio Yamamoto
# ...                      ...              ...
# 29396    Lịch Sử - Chính Trị  Nguyễn Ngọc Huy
# 29397    Lịch Sử - Chính Trị  Nguyễn Ngọc Huy
# 29398    Lịch Sử - Chính Trị  Nguyễn Ngọc Huy
# 29399    Lịch Sử - Chính Trị  Nguyễn Ngọc Huy
# 29400    Lịch Sử - Chính Trị  Nguyễn Ngọc Huy
#
#                                              Description  \
# 0      31 31 31 bụngdưới lễphục size phẳngphiu tưởngt...
# 1      31 31 bụngdưới lễphục size phẳngphiu tưởngtượn...
# 2      31 bụngdưới lễphục size phẳngphiu tưởngtượng m...
# 3      bụngdưới lễphục size phẳngphiu tưởngtượng mẹ đ...
# 4      lễphục size phẳngphiu tưởngtượng mẹ đứa trẻ dá...
# ...                                                  ...
# 29396  vốn trà dư tửu hậu tâmhồn côđơn trốngrỗng sách...
# 29397  trà dư tửu hậu tâmhồn côđơn trốngrỗng sách giả...
# 29398  dư tửu hậu tâmhồn côđơn trốngrỗng sách giảithí...
# 29399  tửu hậu tâmhồn côđơn trốngrỗng sách giảithích ...
# 29400  hậu tâmhồn côđơn trốngrỗng sách giảithích quan...
#
#                                       Description_Ngrams
# 0      (31, 31, 31, bụngdưới, lễphục, size, phẳngphiu...
# 1      (31, 31, bụngdưới, lễphục, size, phẳngphiu, tư...
# 2      (31, bụngdưới, lễphục, size, phẳngphiu, tưởngt...
# 3      (bụngdưới, lễphục, size, phẳngphiu, tưởngtượng...
# 4      (lễphục, size, phẳngphiu, tưởngtượng, mẹ, đứa,...
# ...                                                  ...
# 29396  (vốn, trà, dư, tửu, hậu, tâmhồn, côđơn, trốngr...
# 29397  (trà, dư, tửu, hậu, tâmhồn, côđơn, trốngrỗng, ...
# 29398  (dư, tửu, hậu, tâmhồn, côđơn, trốngrỗng, sách,...
# 29399  (tửu, hậu, tâmhồn, côđơn, trốngrỗng, sách, giả...
# 29400  (hậu, tâmhồn, côđơn, trốngrỗng, sách, giảithíc...
#
# [29401 rows x 6 columns]

# %%
df.drop(columns='Description_Ngrams', inplace=True)
df.head()
# Out:
#                      Title                                               Link  \
# 0  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 1  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 2  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 3  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
# 4  31 Tuổi Thì Đã Làm Sao?  https://khosachonline.com/sach/31-tuoi-thi-da-...
#
#                    Genre          Author  \
# 0  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 1  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 2  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 3  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
# 4  Tâm Lý - Kỹ Năng Sống  Fumio Yamamoto
#
#                                          Description
# 0  31 31 31 bụngdưới lễphục size phẳngphiu tưởngt...
# 1  31 31 bụngdưới lễphục size phẳngphiu tưởngtượn...
# 2  31 bụngdưới lễphục size phẳngphiu tưởngtượng m...
# 3  bụngdưới lễphục size phẳngphiu tưởngtượng mẹ đ...
# 4  lễphục size phẳngphiu tưởngtượng mẹ đứa trẻ dá...

# %%
df['Genre'].value_counts()
# Out:
# Y Học - Sức Khỏe         6338
# Tâm Lý - Kỹ Năng Sống    5968
# Lịch Sử - Chính Trị      3411
# Kinh Tế - Quản Lý        3245
# Marketing - Bán hàng     1733
# Ẩm thực - Nấu ăn         1536
# Văn Hóa - Nghệ Thuật     1526
# Tử Vi - Phong Thủy       1482
# Triết Học                1421
# Tài Liệu Học Tập          778
# Nông - Lâm - Ngư          629
# Học Ngoại Ngữ             522
# Kiến Trúc - Xây Dựng      370
# Thư Viện Pháp Luật        302
# Công Nghệ Thông Tin       102
# Tôn Giáo - Tâm Linh        38
# Name: Genre, dtype: int64

# %%
# Tạo count_vectorize
count_vectorizer = CountVectorizer()
count_vectorizer.fit(df['Description'])
# vectorized_data = count_vectorizer.transform(preprocessed_dataset)

# %%
dictionary = count_vectorizer.vocabulary_

# %%
x = dictionary.keys()
new = {i: 0 for i in x}

# %%
def count_word(text, word):
    return text.count(' '+word+' ')

# %%
for _, row in df.iterrows():
    for word in new.keys():
        new[word] += count_word(row['Description'], word)

# %%
#Thống kê top 10 tần số sử dụng các từ vựng trong tập dữ liệu
dictionary = new
dictionary = dict(sorted(dictionary.items(), key = lambda item: item[1],reverse=True))
list(dictionary.items())
# dictionary

# %%
#Thống kê độ dài trung bình của các dòng chữ liệu
ans = 0
for index, row in df.iterrows():
    ans += len(row['Description'])
ans /= df.shape[0]
ans

# %%
#Create new column for Countvectorize
description_vector = count_vectorizer.fit_transform(df['Description'])
df['Description_vector'] = description_vector.toarray().tolist()
df.head()

# %%
df['Length'] = df['Description'].apply(len)
df.head()

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ histogram
plt.hist(df['Length'], bins=30)

# Đặt tiêu đề và các nhãn trục
plt.title('Frequency of length description')
plt.xlabel('Length')
plt.ylabel('Frequency')

# Hiển thị biểu đồ
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Tạo một instance của TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit và chuyển đổi dữ liệu văn bản thành ma trận TF-IDF
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Description'])

# Cho vao cot moi

df['TFIDF'] = tfidf_matrix.toarray().tolist()
df.head()

# %%
df.to_csv('data_remove_fixed_3.csv')
